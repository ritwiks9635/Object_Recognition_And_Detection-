# %% [markdown]
# <a href="https://colab.research.google.com/github/ritwiks9635/Object_Recognition_And_Detection-/blob/main/YOLO_CAR_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**YoLo Car Object Detection**

# %%
#https://www.kaggle.com/datasets/sshikamaru/car-object-detection

# %%
# !unzip /content/https:/www.kaggle.com/datasets/sshikamaru/car-object-detection/car-object-detection.zip

# %%
import os, time, random
import numpy as np
import pandas as pd
import cv2, torch
from tqdm.auto import tqdm
import shutil as sh

from IPython.display import Image, clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %%time

# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U pycocotools
# !pip install -qr yolov5/requirements.txt  # install dependencies
# !cp yolov5/requirements.txt ./
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16525, done.
# remote: Total 16525 (delta 0), reused 0 (delta 0), pack-reused 16525
# Receiving objects: 100% (16525/16525), 15.06 MiB | 18.65 MiB/s, done.
# Resolving deltas: 100% (11359/11359), done.
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.5/749.5 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 36.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 45.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 41.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 933.5 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 3.4 MB/s eta 0:00:00
# CPU times: user 17.7 s, sys: 2.33 s, total: 20 s
# Wall time: 16min 35s

# %% [markdown]
# #**Loading Data 📝 / Preprocessing ⚙️**

# %%
img_h, img_w, num_channels = (380, 676, 3)
df = pd.read_csv('/content/data/train_solution_bounding_boxes (1).csv')
df.rename(columns={'image':'image_id'}, inplace=True)
df['image_id'] = df['image_id'].apply(lambda x: x.split('.')[0])
df['x_center'] = (df['xmin'] + df['xmax'])/2
df['y_center'] = (df['ymin'] + df['ymax'])/2
df['w'] = df['xmax'] - df['xmin']
df['h'] = df['ymax'] - df['ymin']
df['classes'] = 0
df['x_center'] = df['x_center']/img_w
df['w'] = df['w']/img_w
df['y_center'] = df['y_center']/img_h
df['h'] = df['h']/img_h
df.head()
# Out:
#       image_id        xmin        ymin        xmax        ymax  x_center  \
# 0   vid_4_1000  281.259045  187.035071  327.727931  223.225547  0.450434
# 1  vid_4_10000   15.163531  187.035071  120.329957  236.430180  0.100217
# 2  vid_4_10040  239.192475  176.764801  361.968162  236.430180  0.444645
# 3  vid_4_10020  496.483358  172.363256  630.020260  231.539575  0.833213
# 4  vid_4_10060   16.630970  186.546010  132.558611  238.386422  0.110347
#
#    y_center         w         h  classes
# 0  0.539817  0.068741  0.095238        0
# 1  0.557191  0.155572  0.129987        0
# 2  0.543678  0.181621  0.157014        0
# 3  0.531451  0.197540  0.155727        0
# 4  0.559122  0.171491  0.136422        0

# %%
index = list(set(df.image_id))
image = random.choice(index)
print("Image ID: %s"%(image))
img = cv2.imread(f'/content/data/training_images/{image}.jpg')
img.shape
# Out:
# Image ID: vid_4_9280
# (380, 676, 3)

# %%
image = random.choice(index)
Image(filename=f'/content/data/training_images/{image}.jpg',width=600)

# %%
source = 'training_images'
if True:
    for fold in [0]:
        val_index = index[len(index)*fold//5:len(index)*(fold+1)//5]
        for name,mini in tqdm(df.groupby('image_id')):
            if name in val_index:
                path2save = 'val2017/'
            else:
                path2save = 'train2017/'
            if not os.path.exists('/content/convertor/fold{}/labels/'.format(fold)+path2save):
                os.makedirs('/content/convertor/fold{}/labels/'.format(fold)+path2save)
            with open('/content/convertor/fold{}/labels/'.format(fold)+path2save+name+".txt", 'w+') as f:
                row = mini[['classes','x_center','y_center','w','h']].astype(float).values
                row = row.astype(str)
                for j in range(len(row)):
                    text = ' '.join(row[j])
                    f.write(text)
                    f.write("\n")
            if not os.path.exists('/content/convertor/fold{}/images/{}'.format(fold,path2save)):
                os.makedirs('/content/convertor/fold{}/images/{}'.format(fold,path2save))
            sh.copy("/content/data/{}/{}.jpg".format(source,name),'/tmp/convertor/fold{}/images/{}/{}.jpg'.format(fold,path2save,name))
# Out:
#   0%|          | 0/355 [00:00<?, ?it/s]

# %%
#!python train.py --batch 2 --epochs 1 --data ../input/yolov5-config/car.yaml --cfg ../input/yolov5-config/yolov5x.yaml --name yolov5x_fold0_new

# %% [markdown]
# ##**Prediction**

# %%
# !python yolov5/detect.py --weights yolov5/yolov5s.pt --img 676 --conf 0.4 --source /content/data/testing_images
# Out:
# detect: weights=['yolov5/yolov5s.pt'], source=/content/data/testing_images, data=yolov5/data/coco128.yaml, imgsz=[676, 676], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ --img-size [676, 676] must be multiple of max stride 32, updating to [704, 704]
# image 1/175 /content/data/testing_images/vid_5_25100.jpg: 416x704 (no detections), 587.9ms
# image 2/175 /content/data/testing_images/vid_5_25120.jpg: 416x704 (no detections), 533.3ms
# image 3/175 /content/data/testing_images/vid_5_25140.jpg: 416x704 (no detections), 455.8ms
# image 4/175 /content/data/testing_images/vid_5_25160.jpg: 416x704 (no detections), 322.8ms
# image 5/175 /content/data/testing_images/vid_5_25180.jpg: 416x704 (no detections), 302.4ms
# image 6/175 /content/data/testing_images/vid_5_25200.jpg: 416x704 (no detections), 295.7ms
# image 7/175 /content/data/testing_images/vid_5_25220.jpg: 416x704 (no detections), 308.1ms
# image 8/175 /content/data/testing_images/vid_5_25240.jpg: 416x704 (no detections), 293.9ms
# image 9/175 /content/data/testing_images/vid_5_25260.jpg: 416x704 (no detections), 303.9ms
# image 10/175 /content/data/testing_images/vid_5_26320.jpg: 416x704 (no detections), 308.0ms
# image 11/175 /content/data/testing_images/vid_5_26400.jpg: 416x704 (no detections), 294.2ms
# image 12/175 /content/data/testing_images/vid_5_26420.jpg: 416x704 (no detections), 293.5ms
# image 13/175 /content/data/testing_images/vid_5_26560.jpg: 416x704 1 car, 293.2ms
# image 14/175 /content/data/testing_images/vid_5_26580.jpg: 416x704 1 car, 307.5ms
# image 15/175 /content/data/testing_images/vid_5_26600.jpg: 416x704 2 cars, 299.2ms
# image 16/175 /content/data/testing_images/vid_5_26620.jpg: 416x704 1 car, 317.7ms
# image 17/175 /content/data/testing_images/vid_5_26640.jpg: 416x704 3 cars, 307.9ms
# image 18/175 /content/data/testing_images/vid_5_26660.jpg: 416x704 1 car, 303.9ms
# image 19/175 /content/data/testing_images/vid_5_26680.jpg: 416x704 3 cars, 1 truck, 295.0ms
# image 20/175 /content/data/testing_images/vid_5_26700.jpg: 416x704 2 cars, 307.4ms
# image 118/175 /content/data/testing_images/vid_5_29740.jpg: 416x704 (no detections), 302.1ms
# image 119/175 /content/data/testing_images/vid_5_29760.jpg: 416x704 1 car, 309.7ms
# image 120/175 /content/data/testing_images/vid_5_29820.jpg: 416x704 1 car, 304.7ms
# image 121/175 /content/data/testing_images/vid_5_29840.jpg: 416x704 1 car, 1 truck, 292.5ms
# image 122/175 /content/data/testing_images/vid_5_29860.jpg: 416x704 (no detections), 295.1ms
# image 123/175 /content/data/testing_images/vid_5_29880.jpg: 416x704 (no detections), 309.6ms
# image 124/175 /content/data/testing_images/vid_5_29900.jpg: 416x704 (no detections), 295.5ms
# image 125/175 /content/data/testing_images/vid_5_29980.jpg: 416x704 1 person, 300.9ms
# image 126/175 /content/data/testing_images/vid_5_30000.jpg: 416x704 (no detections), 307.3ms
# image 127/175 /content/data/testing_images/vid_5_30020.jpg: 416x704 (no detections), 299.5ms
# image 128/175 /content/data/testing_images/vid_5_30040.jpg: 416x704 (no detections), 318.6ms
# image 129/175 /content/data/testing_images/vid_5_30120.jpg: 416x704 (no detections), 309.5ms
# image 130/175 /content/data/testing_images/vid_5_30140.jpg: 416x704 (no detections), 290.1ms
# image 131/175 /content/data/testing_images/vid_5_30160.jpg: 416x704 (no detections), 297.6ms
# image 132/175 /content/data/testing_images/vid_5_30180.jpg: 416x704 (no detections), 309.9ms
# image 133/175 /content/data/testing_images/vid_5_30640.jpg: 416x704 1 car, 301.4ms
# image 134/175 /content/data/testing_images/vid_5_30660.jpg: 416x704 (no detections), 294.9ms
# image 135/175 /content/data/testing_images/vid_5_30680.jpg: 416x704 (no detections), 302.0ms
# image 136/175 /content/data/testing_images/vid_5_30700.jpg: 416x704 (no detections), 298.4ms
# image 137/175 /content/data/testing_images/vid_5_30720.jpg: 416x704 (no detections), 292.5ms
# image 138/175 /content/data/testing_images/vid_5_30740.jpg: 416x704 1 car, 1 truck, 300.5ms
# image 139/175 /content/data/testing_images/vid_5_30760.jpg: 416x704 1 car, 3 traffic lights, 308.0ms
# image 140/175 /content/data/testing_images/vid_5_30820.jpg: 416x704 2 cars, 6 traffic lights, 301.1ms
# image 141/175 /content/data/testing_images/vid_5_30840.jpg: 416x704 2 cars, 5 traffic lights, 292.9ms
# image 142/175 /content/data/testing_images/vid_5_30860.jpg: 416x704 3 cars, 3 traffic lights, 313.6ms
# image 143/175 /content/data/testing_images/vid_5_30920.jpg: 416x704 2 cars, 2 traffic lights, 291.0ms
# image 144/175 /content/data/testing_images/vid_5_30940.jpg: 416x704 2 cars, 2 traffic lights, 305.5ms
# image 145/175 /content/data/testing_images/vid_5_31020.jpg: 416x704 2 cars, 352.6ms
# image 146/175 /content/data/testing_images/vid_5_31040.jpg: 416x704 3 cars, 468.0ms
# image 147/175 /content/data/testing_images/vid_5_31060.jpg: 416x704 1 car, 471.4ms
# image 148/175 /content/data/testing_images/vid_5_31080.jpg: 416x704 2 cars, 456.7ms
# image 149/175 /content/data/testing_images/vid_5_31100.jpg: 416x704 1 car, 459.6ms
# image 150/175 /content/data/testing_images/vid_5_31120.jpg: 416x704 2 cars, 443.3ms
# image 151/175 /content/data/testing_images/vid_5_31140.jpg: 416x704 1 car, 299.6ms
# image 152/175 /content/data/testing_images/vid_5_31160.jpg: 416x704 1 car, 309.4ms
# image 153/175 /content/data/testing_images/vid_5_31180.jpg: 416x704 (no detections), 295.9ms
# image 154/175 /content/data/testing_images/vid_5_31200.jpg: 416x704 (no detections), 274.2ms
# image 155/175 /content/data/testing_images/vid_5_31260.jpg: 416x704 (no detections), 285.2ms
# image 156/175 /content/data/testing_images/vid_5_31280.jpg: 416x704 (no detections), 297.3ms
# image 157/175 /content/data/testing_images/vid_5_31300.jpg: 416x704 (no detections), 296.1ms
# image 158/175 /content/data/testing_images/vid_5_31360.jpg: 416x704 (no detections), 302.9ms
# image 159/175 /content/data/testing_images/vid_5_31380.jpg: 416x704 (no detections), 311.9ms
# image 160/175 /content/data/testing_images/vid_5_31400.jpg: 416x704 (no detections), 282.2ms
# image 161/175 /content/data/testing_images/vid_5_31420.jpg: 416x704 (no detections), 294.2ms
# image 162/175 /content/data/testing_images/vid_5_31480.jpg: 416x704 (no detections), 310.2ms
# image 163/175 /content/data/testing_images/vid_5_31500.jpg: 416x704 (no detections), 289.8ms
# image 164/175 /content/data/testing_images/vid_5_31520.jpg: 416x704 (no detections), 294.4ms
# image 165/175 /content/data/testing_images/vid_5_31560.jpg: 416x704 1 car, 276.9ms
# image 166/175 /content/data/testing_images/vid_5_31600.jpg: 416x704 2 cars, 296.4ms
# image 167/175 /content/data/testing_images/vid_5_31620.jpg: 416x704 1 car, 285.7ms
# image 168/175 /content/data/testing_images/vid_5_31640.jpg: 416x704 (no detections), 298.1ms
# image 169/175 /content/data/testing_images/vid_5_31660.jpg: 416x704 (no detections), 295.4ms
# image 170/175 /content/data/testing_images/vid_5_31680.jpg: 416x704 (no detections), 296.4ms
# image 171/175 /content/data/testing_images/vid_5_31700.jpg: 416x704 1 car, 293.5ms
# image 172/175 /content/data/testing_images/vid_5_31720.jpg: 416x704 1 car, 320.1ms
# image 173/175 /content/data/testing_images/vid_5_400.jpg: 416x704 1 car, 305.2ms
# image 174/175 /content/data/testing_images/vid_5_420.jpg: 416x704 1 car, 296.1ms
# image 175/175 /content/data/testing_images/vid_5_440.jpg: 416x704 1 car, 307.5ms
# Speed: 1.1ms pre-process, 322.6ms inference, 3.4ms NMS per image at shape (1, 3, 704, 704)
# Results saved to yolov5/runs/detect/exp2

# %%
predicted_files = []
for (dirpath, dirnames, filenames) in os.walk("yolov5/runs/detect/exp2"):
    predicted_files.extend(filenames)

# %%
len(predicted_files)
# Out:
# 175

# %%
Image(filename=f'yolov5/runs/detect/exp2/{random.choice(predicted_files)}')

# %%
Image(filename=f'yolov5/runs/detect/exp2/{random.choice(predicted_files)}')

# %%
Image(filename=f'yolov5/runs/detect/exp2/{random.choice(predicted_files)}')

# %%
Image(filename=f'yolov5/runs/detect/exp2/{random.choice(predicted_files)}')
